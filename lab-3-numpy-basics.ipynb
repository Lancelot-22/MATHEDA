# %% [markdown]
# # Numpy <hr style = "border:3px solid rgba(19, 29, 225, 1)"></hr>

# %% [markdown]
# <b> Lance Patrick G. De la Peña</b>
# <br> Computer Engineer </br>

# %%
import numpy as np

# %% [markdown]
# # 1D Array

# %%
my_array = [1,2,3]

# %%
type(my_array)
# Out:
# numpy.ndarray

# %%
my_array= np.array([1,2,3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 2D Array

# %%
my_array = np.array([
    [1,2,3],
    [4,5,6]
])
my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.shape(my_array)
# Out:
# (2, 3)

# %%
trans_array = my_array.T
trans_array
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.shape(trans_array)
# Out:
# (3, 2)

# %%
np.sum(trans_array, axis=0)
# Out:
# array([ 6, 15])

# %%
np.sum(trans_array, axis=1)
# Out:
# array([5, 7, 9])

# %% [markdown]
# # Measure of Central Tendency

# %%
resistance = np.array ([
    [10.6,9.1,9.3,9.8,10.5,10.4, 9.5,11,10.4,3,9.8],#Jaguar
    [10.1,11,9.1,20, 9.2,10.8,9.9,9.2,9.1,9.1,np.nan]#Panther
])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
np.nanmean(resistance,axis=1)
# Out:
# array([ 9.4 , 10.75])
