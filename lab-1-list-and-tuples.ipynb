# %% [markdown]
# # List and Tuples <hr style = "border:3px solid rgba(19, 29, 225, 1)"></hr>

# %% [markdown]
# <b> Lance Patrick G. De la Peña</b>
# <br> Computer Engineer </br>

# %% [markdown]
# # Creating a List

# %%
numbers =[1,2,3,4,5,]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ["apple","banana","grape"]
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
mixed_list=[10,'hello',2.5,True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Indexing

# %%
numbers[0]
# Out:
# 1

# %%
numbers[-1]
# Out:
# 5

# %% [markdown]
# # Modifying Elements

# %%
'apple' in fruits
# Out:
# True

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
'apple' in fruits
# Out:
# False

# %% [markdown]
# # Adding Elements

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1,'blueberry')
fruits
# Out:
# ['apple',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'blueberry',
#  'grape',
#  'orange']

# %% [markdown]
# # Removing Elements

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('blueberry')
fruits
# Out:
# ['apple', 'grape', 'orange']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grape', 'orange']

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers =[5,3,4,1]

# %%
sorted(numbers, reverse=True)
# Out:
# [5, 4, 3, 1]

# %%
numbers
# Out:
# [1, 3, 4, 5]

# %%
numbers.sort()

# %% [markdown]
# # Slicing

# %%
chars=["a","b","c","d","e"]
chars
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
len(chars)
# Out:
# 5

# %%
chars[1:4]
# Out:
# ['b', 'c', 'd']

# %%
chars[0:5:2]
# Out:
# ['a', 'c', 'e']

# %% [markdown]
# # Tuple

# %%
my_tuple =(1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
mixed_tuple = (10, 'hello', 2.5,True)
mixed_tuple
# Out:
# (10, 'hello', 2.5, True)
